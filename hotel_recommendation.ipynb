# %%
import pandas as pd
hotel_details=pd.read_csv('E:\Downloads\mca_project\data_set2\Hotel_details.csv',delimiter=',')
hotel_rooms=pd.read_csv('E:\Downloads\mca_project\data_set2\Hotel_Room_attributes.csv',delimiter=',')
hotel_cost=pd.read_csv('e:\Downloads\mca_project\data_set2\hotels_RoomPrice.csv',delimiter=',')

# %%
hotel_details
# Out:
#             id  hotelid                  hotelname  \
# 0        46406  1771651   Mediteran Bungalow Galeb
# 1        46407   177167              Hotel Polonia
# 2        46408  1771675          Rifugio Sass Bece
# 3        46409   177168             Madalena Hotel
# 4        46410  1771718          Pension Morenfeld
# ...        ...      ...                        ...
# 108043  154449  1771620     Hotel Stadt Tuttlingen
# 108044  154450  1771626                Hotel Beroe
# 108045  154451   177163             Hotel Rothmans
# 108046  154452   177164  Boutique Suites Rainbow 4
# 108047  154453   177165            Hotel Rainbow 2
#
#                                address         city   country  zipcode  \
# 0                         Vukovarska 7         Omis   Croatia  21310.0
# 1                     Plac Teatralny 5        Torun    Poland      NaN
# 2               Belvedere del Pordoi,1      Canazei     Italy  38032.0
# 3                              Mykonos      Mykonos    Greece  84600.0
# 4               Mair im Korn Strasse 2      Lagundo     Italy  39022.0
# ...                                ...          ...       ...      ...
# 108043                 Donaustrasse 30   Tuttlingen   Germany  78532.0
# 108044                   15 Yasen Str.   Sveti Vlas  Bulgaria   8256.0
# 108045                   14 Ohrid Str.       Bansko  Bulgaria   2770.0
# 108046                     Cacao Beach  Sunny Beach  Bulgaria   8240.0
# 108047  South Sunny beach, Cacao Beach  Sunny Beach  Bulgaria   8240.0
#
#          propertytype  starrating   latitude  longitude  Source  \
# 0       Holiday parks           4  43.440124  16.682505       2
# 1              Hotels           3  53.012329  18.603800       5
# 2              Hotels           3  46.477920  11.813350       2
# 3              Hotels           3  37.452316  25.329849       5
# 4              Hotels           3  46.682780  11.131736       2
# ...               ...         ...        ...        ...     ...
# 108043         Hotels           3  47.985364   8.817228       2
# 108044         Hotels           3  42.710919  27.763325       2
# 108045         Hotels           3  41.837379  23.492391       2
# 108046         Hotels           3  42.674317  27.704325       2
# 108047         Hotels           3  42.674830  27.705092       2
#
#                                                       url curr
# 0       https://www.booking.com/hotel/hr/bungalow-luxu...  EUR
# 1       https://www.agoda.com/en-gb/hotel-polonia/hote...  EUR
# 2       http://www.booking.com/hotel/it/rifugio-sass-b...  EUR
# 3       https://www.agoda.com/en-gb/madalena-hotel/hot...  EUR
# 4       http://www.booking.com/hotel/it/pension-morenf...  EUR
# ...                                                   ...  ...
# 108043  http://www.booking.com/hotel/de/stadt-tuttling...  EUR
# 108044   http://www.booking.com/hotel/bg/beroe.en-gb.html  BGN
# 108045  http://www.booking.com/hotel/bg/rothmans-bansk...  BGN
# 108046  https://www.booking.com/hotel/bg/rainbow-4-bou...  BGN
# 108047  http://www.booking.com/hotel/bg/rainbow-2-caca...  BGN
#
# [108048 rows x 14 columns]

# %%
hotel_rooms
# Out:
#               id  hotelcode  \
# 0       50677497     634876
# 1       50672149    8328096
# 2       50643430    8323442
# 3       50650317       7975
# 4       50650318       7975
# ...          ...        ...
# 165868  88527729     268416
# 165869  88527730     268416
# 165870  88527731     268416
# 165871  88527215     268416
# 165872  88528182     268416
#
#                                             roomamenities  \
# 0       Air conditioning: ;Alarm clock: ;Carpeting: ;C...
# 1       Air conditioning: ;Closet: ;Fireplace: ;Free W...
# 2       Air conditioning: ;Closet: ;Dishwasher: ;Firep...
# 3       Air conditioning: ;Clothes rack: ;Coffee/tea m...
# 4       Air conditioning: ;Clothes rack: ;Coffee/tea m...
# ...                                                   ...
# 165868  Air conditioning: ;Alarm clock: ;Carpeting: ;C...
# 165869  Air conditioning: ;Alarm clock: ;Carpeting: ;C...
# 165870  Air conditioning: ;Alarm clock: ;Carpeting: ;C...
# 165871  Air conditioning: ;Free Wi-Fi in all rooms!: ;...
# 165872  Air conditioning: ;Free Wi-Fi in all rooms!: ;...
#
#                     roomtype  \
# 0                Double Room
# 1              Vacation Home
# 2              Vacation Home
# 3       Standard Triple Room
# 4       Standard Triple Room
# ...                      ...
# 165868             Twin Room
# 165869             Twin Room
# 165870             Twin Room
# 165871         Twin Standard
# 165872       Double Standard
#
#                                           ratedescription
# 0            Room size: 15 m²/161 ft², Shower, 1 king bed
# 1       Shower, Kitchenette, 2 bedrooms, 1 double bed ...
# 2       Shower, Kitchenette, 2 bedrooms, 1 double bed ...
# 3         Room size: 20 m²/215 ft², Shower, 3 single beds
# 4         Room size: 20 m²/215 ft², Shower, 3 single beds
# ...                                                   ...
# 165868  Room size: 17 m²/183 ft², Non-smoking, Shower,...
# 165869  Room size: 17 m²/183 ft², Non-smoking, Shower,...
# 165870  Room size: 17 m²/183 ft², Non-smoking, Shower,...
# 165871  Pay nothing until November 21, 2019, Free Wi-F...
# 165872  Pay nothing until November 21, 2019, Free Wi-F...
#
# [165873 rows x 5 columns]

# %%
hotel_cost
# Out:
#               id    refid  hotelcode  websitecode          dtcollected  \
# 0       50677497  8646773     634876            5  2019-10-12 15:46:54
# 1       50672149  6234691    8328096            5  2019-10-12 15:47:45
# 2       50643430  7015677    8323442            5  2019-10-12 15:47:00
# 3       50650317  7327094       7975            5  2019-10-12 15:47:02
# 4       50650318  7327094       7975            5  2019-10-12 15:47:02
# ...          ...      ...        ...          ...                  ...
# 165868  88527729  9572875     268416            5  2019-10-13 01:03:10
# 165869  88527730  9572875     268416            5  2019-10-13 01:03:10
# 165870  88527731  9572875     268416            5  2019-10-13 01:03:10
# 165871  88527215  9572875     268416            5  2019-10-13 01:03:11
# 165872  88528182  9572875     268416            5  2019-10-13 01:03:11
#
#           ratedate  los  guests              roomtype  onsiterate  ...  \
# 0       2019-11-02    1       1           Double Room       82.36  ...
# 1       2019-11-30    1       1         Vacation Home      636.09  ...
# 2       2019-12-20    1       1         Vacation Home      591.74  ...
# 3       2019-12-28    1       1  Standard Triple Room      881.48  ...
# 4       2019-12-28    1       1  Standard Triple Room      897.53  ...
# ...            ...  ...     ...                   ...         ...  ...
# 165868  2019-11-26    1       1             Twin Room       81.83  ...
# 165869  2019-11-26    1       1             Twin Room       89.80  ...
# 165870  2019-11-26    1       1             Twin Room       99.78  ...
# 165871  2019-11-26    1       1         Twin Standard       70.13  ...
# 165872  2019-11-26    1       1       Double Standard       70.13  ...
#
#         promoname status_code taxstatus       taxtype taxamount  \
# 0             NaN         200         2           NaN       0.0
# 1             NaN         200         2           NaN       0.0
# 2             NaN         200         2           NaN       0.0
# 3             NaN         200         2       Tax 20%       0.0
# 4             NaN         200         2  VAT $ 179.51       0.0
# ...           ...         ...       ...           ...       ...
# 165868        NaN         200         2   VAT $ 16.37       0.0
# 165869        NaN         200         2   VAT $ 17.97       0.0
# 165870        NaN         200         2   VAT $ 19.96       0.0
# 165871        NaN         200         2       Tax 20%       0.0
# 165872        NaN         200         2       Tax 20%       0.0
#
#                                   proxyused  israteperstay  \
# 0        media:M3diAproxy@173.44.165.126:80              Y
# 1        media:M3diAproxy@173.44.164.126:80              Y
# 2        media:M3diAproxy@173.44.166.122:80              Y
# 3       media:M3diAproxy@209.242.219.141:80              Y
# 4       media:M3diAproxy@209.242.219.141:80              Y
# ...                                     ...            ...
# 165868   media:M3diAproxy@173.44.166.122:80              Y
# 165869   media:M3diAproxy@173.44.166.122:80              Y
# 165870   media:M3diAproxy@173.44.166.122:80              Y
# 165871   media:M3diAproxy@173.44.166.122:80              Y
# 165872   media:M3diAproxy@173.44.166.122:80              Y
#
#              mealinclusiontype hotelblock  input_dtcollected
# 0               Free Breakfast        NaN         2019-10-13
# 1                          NaN        NaN         2019-10-13
# 2                          NaN        NaN         2019-10-13
# 3                          NaN        NaN         2019-10-13
# 4       Free breakfast for {3}        NaN         2019-10-13
# ...                        ...        ...                ...
# 165868                     NaN        NaN         2019-10-13
# 165869  Free breakfast for {2}        NaN         2019-10-13
# 165870  Free breakfast for {2}        NaN         2019-10-13
# 165871                     NaN        NaN         2019-10-13
# 165872                     NaN        NaN         2019-10-13
#
# [165873 rows x 30 columns]

# %%
del hotel_details['id']
del hotel_rooms['id']
del hotel_details['zipcode']

# %%
hotel_details=hotel_details.dropna()
hotel_rooms=hotel_rooms.dropna()

# %%
hotel_details.drop_duplicates(subset='hotelid',keep=False,inplace=True)
# Out:
# C:\Users\Ramesh\AppData\Local\Temp\ipykernel_32388\29763760.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_details.drop_duplicates(subset='hotelid',keep=False,inplace=True)

# %%
hotel=pd.merge(hotel_rooms,hotel_details,left_on='hotelcode',right_on='hotelid',how='inner')

# %%
hotel.columns
# Out:
# Index(['hotelcode', 'roomamenities', 'roomtype', 'ratedescription', 'hotelid',
#        'hotelname', 'address', 'city', 'country', 'propertytype', 'starrating',
#        'latitude', 'longitude', 'Source', 'url', 'curr'],
#       dtype='object')

# %%
del hotel['hotelid']
del hotel['url']
del hotel['curr']
del hotel['Source']

# %%
hotel.columns
# Out:
# Index(['hotelcode', 'roomamenities', 'roomtype', 'ratedescription',
#        'hotelname', 'address', 'city', 'country', 'propertytype', 'starrating',
#        'latitude', 'longitude'],
#       dtype='object')

# %%
def citybased(city):
    hotel['city']=hotel['city'].str.lower()
    citybase=hotel[hotel['city']==city.lower()]
    citybase=citybase.sort_values(by='starrating',ascending=False)
    citybase.drop_duplicates(subset='hotelcode',keep='first',inplace=True)
    if(citybase.empty==0):
        hname=citybase[['hotelname','starrating','address','roomamenities','ratedescription']]
        return hname.head()
    else:
        print('No Hotels Available')

# %%
print('Top 5 hotels')
citybased('London')
# Out:
# Top 5 hotels
#                                   hotelname  starrating  \
# 48985            The Colonnade London Hotel           4
# 58663    South Point Suites - London Bridge           4
# 106943  Doubletree by Hilton London Chelsea           4
# 57452      Sir Christopher Wren Hotel & Spa           4
# 92479              The Manor Hotel Heathrow           4
#
#                              address  \
# 48985          2 Warrington Crescent
# 58663              Bermondsey Street
# 106943  Imperial Road Imperial Wharf
# 57452                        Unknown
# 92479        Village Green, Datchet,
#
#                                             roomamenities  \
# 48985   Additional toilet: ;Air conditioning: ;Alarm c...
# 58663   Air conditioning: ;Alarm clock: ;Blackout curt...
# 106943  Air conditioning: ;Alarm clock: ;Blackout curt...
# 57452   Air conditioning: ;Alarm clock: ;Bathrobes: ;B...
# 92479   Additional bathroom: ;Additional toilet: ;Air ...
#
#                                           ratedescription
# 48985   Room size: 28 m²/301 ft², Balcony/terrace, Non...
# 58663   Room size: 24 m²/258 ft², Street view, Non-smo...
# 106943  Room size: 20 m²/215 ft², Street view, Non-smo...
# 57452   Room size: 25 m²/269 ft², Non-smoking, Shower ...
# 92479                    Shower and bathtub, 1 double bed

# %%
room_no=[
     ('king',2),
   ('queen',2), 
    ('triple',3),
    ('master',3),
   ('family',4),
   ('murphy',2),
   ('quad',4),
   ('double-double',4),
   ('mini',2),
   ('studio',1),
    ('junior',2),
   ('apartment',4),
    ('double',2),
   ('twin',2),
   ('double-twin',4),
   ('single',1),
     ('diabled',1),
   ('accessible',1),
    ('suite',2),
    ('one',2)
   ]

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
import numpy as np

# %%
def calc():
    guests_no=[]
    for i in range(hotel.shape[0]):
        temp=hotel['roomtype'][i].lower().split()
        flag=0
        for j in range(len(temp)):
            for k in range(len(room_no)):
                if temp[j]==room_no[k][0]:
                    guests_no.append(room_no[k][1])
                    flag=1
                    break
            if flag==1:
                break
        if flag==0:
            guests_no.append(2)
    hotel['guests_no']=guests_no

calc()

# %%
hotel['roomamenities']=hotel['roomamenities'].str.replace(': ;',',')

# %%
def requirementbased(city,number,features):
    hotel['city']=hotel['city'].str.lower()
    hotel['roomamenities']=hotel['roomamenities'].str.lower()
    features=features.lower()
    features_tokens=word_tokenize(features)  
    sw = stopwords.words('english')
    lemm = WordNetLemmatizer()
    f1_set = {w for w in features_tokens if not w in sw}
    f_set=set()
    for se in f1_set:
        f_set.add(lemm.lemmatize(se))
    reqbased=hotel[hotel['city']==city.lower()]
    reqbased=reqbased[reqbased['guests_no']==number]
    reqbased=reqbased.set_index(np.arange(reqbased.shape[0]))
    l1 =[];l2 =[];cos=[];
    #print(reqbased['roomamenities'])
    for i in range(reqbased.shape[0]):
        temp_tokens=word_tokenize(reqbased['roomamenities'][i])
        temp1_set={w for w in temp_tokens if not w in sw}
        temp_set=set()
        for se in temp1_set:
            temp_set.add(lemm.lemmatize(se))
        rvector = temp_set.intersection(f_set)
        #print(rvector)
        cos.append(len(rvector))
    reqbased['similarity']=cos
    reqbased=reqbased.sort_values(by='similarity',ascending=False)
    reqbased.drop_duplicates(subset='hotelcode',keep='first',inplace=True)
    return reqbased[['city','hotelname','roomtype','guests_no','starrating','address','roomamenities','ratedescription','similarity']].head(10)

# %%
requirementbased('London',4,'I need air conditioned room. I should have an alarm clock.')
# Out:
#        city                               hotelname  \
# 0    london        Holiday Inn London - Heathrow T5
# 281  london                 Courtyard Luton Airport
# 292  london              The Colonnade London Hotel
# 722  london                 Sheraton Heathrow Hotel
# 270  london                 Best Western Palm Hotel
# 246  london         Best Western Burns Hotel London
# 294  london                          Princess Hotel
# 313  london    Comfort Inn St Pancras - Kings Cross
# 799  london  Sheraton Skyline Hotel London Heathrow
# 775  london                        Barrington Lodge
#
#                                               roomtype  guests_no  starrating  \
# 0                                          Family Room          4           4
# 281  Superior Family Room, Guest room, 1 King, Sofa...          4           4
# 292                     Three-Bedroom Luxury Apartment          4           4
# 722             Family Room 1Twin, Guest room, 1 Queen          4           4
# 270  Family Room with 1 Double Bed and 1 Single Bed...          4           3
# 246                                        Family Room          4           3
# 294            Basic Family Room with Shared Bathroom           4           2
# 313                                             Family          4           3
# 799                  Family Room, Guest room, 2 Double          4           4
# 775                                Deluxe Family Suite          4           4
#
#                          address  \
# 0                  Old Bath Road
# 281                  Airport Way
# 292        2 Warrington Crescent
# 722             Heathrow Airport
# 270             64-76 Hendon Way
# 246       18-26 Barkston Gardens
# 294          35-39 Argyle Street
# 313        2-5 St. Chad's Street
# 799  Heathrow Airport, Bath Road
# 775                  Hunter Road
#
#                                          roomamenities  \
# 0    air conditioning,alarm clock,blackout curtains...
# 281  additional toilet,air conditioning,alarm clock...
# 292  additional bathroom,additional toilet,air cond...
# 722  air conditioning,alarm clock,bathrobes,closet,...
# 270  additional toilet,air conditioning,alarm clock...
# 246  air conditioning,alarm clock,carpeting,closet,...
# 294  air conditioning,alarm clock,carpeting,closet,...
# 313  air conditioning,alarm clock,coffee/tea maker,...
# 799  air conditioning,alarm clock,bathrobes,carpeti...
# 775  air conditioning,alarm clock,carpeting,closet,...
#
#                                        ratedescription  similarity
# 0    Room size: 25 m²/269 ft², Non-smoking, Separat...           4
# 281                  Shower, 1 king bed and 1 sofa bed           4
# 292  Room size: 121 m²/1302 ft², 2 bathrooms, Showe...           4
# 722                                 Shower, 1 king bed           4
# 270  Room size: 26 m²/280 ft², Non-smoking, Shower,...           4
# 246  Room size: 20 m²/215 ft², Separate shower/bath...           4
# 294  Room size: 20 m²/215 ft², Non-smoking, Shared ...           4
# 313  Room size: 20 m²/215 ft², Non-smoking, Shower,...           4
# 799     Non-smoking, Shower and bathtub, 2 double beds           4
# 775  Room size: 30 m²/323 ft², Shower, 1 king bed a...           4

# %%
def ratebased(city,number,features):
    hotel['city']=hotel['city'].str.lower()
    hotel['ratedescription']=hotel['ratedescription'].str.lower()
    features=features.lower()
    features_tokens=word_tokenize(features)  
    sw = stopwords.words('english')
    lemm = WordNetLemmatizer()
    f1_set = {w for w in features_tokens if not w in sw}
    f_set=set()
    for se in f1_set:
        f_set.add(lemm.lemmatize(se))
    rtbased=hotel[hotel['city']==city.lower()]
    rtbased=rtbased[rtbased['guests_no']==number]
    rtbased=rtbased.set_index(np.arange(rtbased.shape[0]))
    l1 =[];l2 =[];cos=[];
    
    for i in range(rtbased.shape[0]):
        temp_tokens=word_tokenize(rtbased['ratedescription'][i])
        temp1_set={w for w in temp_tokens if not w in sw}
        temp_set=set()
        for se in temp1_set:
            temp_set.add(lemm.lemmatize(se))
        rvector = temp_set.intersection(f_set)
        
        cos.append(len(rvector))
    rtbased['similarity']=cos
    rtbased=rtbased.sort_values(by='similarity',ascending=False)
    rtbased.drop_duplicates(subset='hotelcode',keep='first',inplace=True)
    return rtbased[['city','hotelname','roomtype','guests_no','starrating','address','ratedescription','similarity']].head(10)

# %%
ratebased('London',4,'I need free wifi.')
# Out:
#        city                                       hotelname  \
# 710  london                                   Grantly Hotel
# 454  london                          The Heathrow Inn Hotel
# 696  london  Radisson Blu Edwardian Kenilworth - Bloomsbury
# 423  london      The Park City Grand Plaza Kensington Hotel
# 273  london                         Best Western Palm Hotel
# 408  london       Ramada by Wyndham London Stansted Airport
# 849  london                       The Bridge Hotel Chertsey
# 572  london                                   Dolphin Hotel
# 521  london               The Thistle Bloomsbury Park Hotel
# 807  london                             The Cleveland Hotel
#
#                     roomtype  guests_no  starrating  \
# 710       Standard Quad Room          4           3
# 454     Family Room 5 people          4           3
# 696          Standard Family          4           4
# 423  Family Room - Room Only          4           4
# 273     Family room Standard          4           3
# 408              Family Room          4           3
# 849       Family Double Room          4           3
# 572   Family Room Capacity 5          4           2
# 521     Family Room Standard          4           4
# 807            Family Studio          4           4
#
#                                                address  \
# 710                            50 Shepherds Bush Green
# 454                               140 Coldharbour Lane
# 696                            97 Great Russell Street
# 423                               18-30 Lexham Gardens
# 273                                   64-76 Hendon Way
# 408  Birchanger Green Services, M11, Junction 8,Old...
# 849                              Bridge Road, Chertsey
# 572                               32-34 Norfolk Square
# 521                                126 Southampton Row
# 807                             39-40 Cleveland Square
#
#                                        ratedescription  similarity
# 710  free wi-fi, extra low price! (non-refundable),...           2
# 454      free wi-fi, extra low price! (non-refundable)           1
# 696                    free wi-fi, cancellation policy           1
# 423      free wi-fi, extra low price! (non-refundable)           1
# 273  pay nothing until december 27, 2019, free wi-f...           1
# 408      free wi-fi, extra low price! (non-refundable)           1
# 849  pay at the hotel, free wi-fi, free cancellatio...           1
# 572  free breakfast, pay nothing until december 26,...           1
# 521                    free wi-fi, cancellation policy           1
# 807      free wi-fi, extra low price! (non-refundable)           1
